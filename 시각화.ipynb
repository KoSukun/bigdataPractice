# %%
import time
print("Sleeping");
time.sleep(3); # sleep for a while: interrupt me!
print("Done Sleeping");
# Out:
# Sleeping
# Done Sleeping

# %%
# %%html
# <font color="red">안녕? 나는 HTML이야</font>
# Out:
# <font color="red">안녕? 나는 HTML이야</font>

# %%
# %%html
# <marquee style="width: 30%, color:blue;"><b>파이팅</b></marquee>
# Out:
# <marquee style="width: 30%, color:blue;"><b>파이팅</b></marquee>

# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
y = 200 + np.random.randn(100);

# %%
x = [x for x in range(len(y))];

# %%
plt.plot(x, y, "-");
plt.title("Filled Example");
plt.show();

# %%
plt.plot(x, y, "^");
plt.title("Filled Example");
plt.show();

# %%
plt.plot(x, y, "o");
plt.title("Filled Example");
plt.show();

# %%
plt.plot(x, y, "-");
plt.title("Filled Example");
plt.fill_between(x, y, 195, where=(y>195), facecolor="g", alpha=0.6);
plt.show();
